# %%
#!pip install cloudscraper
# Out:
# Collecting cloudscraper
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\karlj\anaconda3\lib\site-packages (from cloudscraper) (3.2.0)
# Requirement already satisfied: requests>=2.9.2 in c:\users\karlj\anaconda3\lib\site-packages (from cloudscraper) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\karlj\anaconda3\lib\site-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karlj\anaconda3\lib\site-packages (from requests>=2.9.2->cloudscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karlj\anaconda3\lib\site-packages (from requests>=2.9.2->cloudscraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karlj\anaconda3\lib\site-packages (from requests>=2.9.2->cloudscraper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karlj\anaconda3\lib\site-packages (from requests>=2.9.2->cloudscraper) (2025.11.12)
# Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
# Installing collected packages: cloudscraper
# Successfully installed cloudscraper-1.2.71

# %%
import cloudscraper
import pandas as pd
import re

url = "https://fbref.com/en/comps/9/Premier-League-Stats"

scraper = cloudscraper.create_scraper()
html = scraper.get(url).text

tables = pd.read_html(html, attrs={"id": "results2025-202691_overall"})
df = tables[0]


if isinstance(df.columns, pd.MultiIndex):
    df.columns = [
        " ".join([str(c) for c in col if str(c) != ""]).strip()
        for col in df.columns
    ]
else:
    df.columns = [str(c).strip() for c in df.columns]

def clean_col(col: str) -> str:
    col = col.replace("\xa0", " ")
    col = re.sub(r"[_·]+", " ", col)
    col = re.sub(r"\s+", " ", col)
    return col.strip()

df.columns = [clean_col(c) for c in df.columns]

print(df.columns.tolist())
df.head()
# Out:
# ['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP', 'xG', 'xGA', 'xGD', 'xGD/90', 'Last 5', 'Attendance', 'Top Team Scorer', 'Goalkeeper', 'Notes']
# C:\Users\karlj\AppData\Local\Temp\ipykernel_252\678812599.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, attrs={"id": "results2025-202691_overall"})
#    Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1          Arsenal  11  8  2  1  20   5  15   26    2.36  18.8   6.0
# 1   2  Manchester City  11  7  1  3  23   8  15   22    2.00  19.3  10.3
# 2   3          Chelsea  11  6  2  3  21  11  10   20    1.82  20.4  13.4
# 3   4       Sunderland  11  5  4  2  14  10   4   19    1.73  10.2  13.2
# 4   5        Tottenham  11  5  3  3  19  10   9   18    1.64  11.0  15.2
#
#     xGD  xGD/90     Last 5  Attendance      Top Team Scorer  \
# 0  12.8    1.16  W W W W D       60144  Viktor Gyökeres - 4
# 1   9.0    0.82  W W L W W       52344  Erling Haaland - 14
# 2   6.9    0.63  W W L W W       39586       João Pedro - 4
# 3  -2.9   -0.27  L W W D D       45602    Wilson Isidor - 4
# 4  -4.2   -0.38  W L W L D       61095      Richarlison - 4
#
#              Goalkeeper  Notes
# 0            David Raya    NaN
# 1  Gianluigi Donnarumma    NaN
# 2        Robert Sánchez    NaN
# 3           Robin Roefs    NaN
# 4     Guglielmo Vicario    NaN

# %%
import re
import pandas as pd
import cloudscraper


def scrape_fbref_leaderboard(url: str, table_id: str) -> pd.DataFrame:
    scraper = cloudscraper.create_scraper()
    html = scraper.get(url).text

    tables = pd.read_html(html, attrs={"id": table_id})
    if not tables:
        raise ValueError(f"Table with id '{table_id}' wasn't found on the page {url}")

    df = tables[0]

    if isinstance(df.columns, pd.MultiIndex):
        df.columns = [
            " ".join([str(c) for c in col if str(c) != ""]).strip()
            for col in df.columns
        ]
    else:
        df.columns = [str(c).strip() for c in df.columns]

    def clean_col_(col: str) -> str:
        col = str(col)
        col = col.replace("\xa0", " ")
        col = re.sub(r"[_·]+", " ", col)
        col = re.sub(r"\s+", " ", col)
        return col.strip()

    df.columns = [clean_col(c) for c in df.columns]

    cols_to_drop = ["Attendance", "Top Team Scorer", "Goalkeeper", "Notes"]
    existing_to_drop = [c for c in cols_to_drop if c in df.columns]
    if existing_to_drop:
        df = df.drop(columns=existing_to_drop)

    return df


def save_df_to_csv(df: pd.DataFrame, filename: str, index: bool = False) -> None:
    df.to_csv(filename, index=index)

# %%
standings25_26 = scrape_fbref_leaderboard("https://fbref.com/en/comps/9/Premier-League-Stats", "results2025-202691_overall")
standings24_25 = scrape_fbref_leaderboard("https://fbref.com/en/comps/9/2024-2025/2024-2025-Premier-League-Stats", "results2024-202591_overall")
standings23_24 = scrape_fbref_leaderboard("https://fbref.com/en/comps/9/2023-2024/2023-2024-Premier-League-Stats", "results2023-202491_overall")
# Out:
# C:\Users\karlj\AppData\Local\Temp\ipykernel_252\1473612847.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, attrs={"id": table_id})
# C:\Users\karlj\AppData\Local\Temp\ipykernel_252\1473612847.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, attrs={"id": table_id})
# C:\Users\karlj\AppData\Local\Temp\ipykernel_252\1473612847.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, attrs={"id": table_id})

# %%
standings25_26.head()
# Out:
#    Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1          Arsenal  11  8  2  1  20   5  15   26    2.36  18.8   6.0
# 1   2  Manchester City  11  7  1  3  23   8  15   22    2.00  19.3  10.3
# 2   3          Chelsea  11  6  2  3  21  11  10   20    1.82  20.4  13.4
# 3   4       Sunderland  11  5  4  2  14  10   4   19    1.73  10.2  13.2
# 4   5        Tottenham  11  5  3  3  19  10   9   18    1.64  11.0  15.2
#
#     xGD  xGD/90     Last 5
# 0  12.8    1.16  W W W W D
# 1   9.0    0.82  W W L W W
# 2   6.9    0.63  W W L W W
# 3  -2.9   -0.27  L W W D D
# 4  -4.2   -0.38  W L W L D

# %%
standings24_25.head()
# Out:
#    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1        Liverpool  38  25   9   4  86  41  45   84    2.21  82.2  38.6
# 1   2          Arsenal  38  20  14   4  69  34  35   74    1.95  59.9  34.4
# 2   3  Manchester City  38  21   8   9  72  44  28   71    1.87  68.1  47.7
# 3   4          Chelsea  38  20   9   9  64  43  21   69    1.82  67.8  47.3
# 4   5    Newcastle Utd  38  20   6  12  68  47  21   66    1.74  63.8  45.5
#
#     xGD  xGD/90
# 0  43.6    1.15
# 1  25.5    0.67
# 2  20.4    0.54
# 3  20.5    0.54
# 4  18.3    0.48

# %%
standings23_24.head()
# Out:
#    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1  Manchester City  38  28   7   3  96  34  62   91    2.39  80.5  35.6
# 1   2          Arsenal  38  28   5   5  91  29  62   89    2.34  76.1  27.9
# 2   3        Liverpool  38  24  10   4  86  41  45   82    2.16  87.8  45.7
# 3   4      Aston Villa  38  20   8  10  76  61  15   68    1.79  63.3  59.9
# 4   5        Tottenham  38  20   6  12  74  61  13   66    1.74  68.2  63.4
#
#     xGD  xGD/90
# 0  44.9    1.18
# 1  48.2    1.27
# 2  42.0    1.11
# 3   3.4    0.09
# 4   4.8    0.13

# %%
save_to_csv(standings25_26, "2025/2026 Team Leaderboard (ONGOING)")

# %%
save_to_csv(standings24_25, "2024/2025 Team Leaderboard (Finished)")

# %%
save_to_csv(standings23_24, "2023/2024 Team Leaderboard (Finished)")
