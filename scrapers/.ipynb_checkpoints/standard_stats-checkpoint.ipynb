# %% [markdown]
# **Scraper for Team Stats**

# %%
# !pip install cloudscraper
# Out:
# Collecting cloudscraper
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in /opt/anaconda3/lib/python3.13/site-packages (from cloudscraper) (3.2.0)
# Requirement already satisfied: requests>=2.9.2 in /opt/anaconda3/lib/python3.13/site-packages (from cloudscraper) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /opt/anaconda3/lib/python3.13/site-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.9.2->cloudscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.9.2->cloudscraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.9.2->cloudscraper) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.9.2->cloudscraper) (2025.10.5)
# Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
# Installing collected packages: cloudscraper
# Successfully installed cloudscraper-1.2.71

# %%
import cloudscraper
import pandas as pd

url = "https://fbref.com/en/comps/9/Premier-League-Stats"

scraper = cloudscraper.create_scraper()

html = scraper.get(url).text

tables = pd.read_html(html, attrs={"id": "stats_squads_standard_for"})
df = tables[0]
# Out:
# /var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T/ipykernel_81859/312814577.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, attrs={"id": "stats_squads_standard_for"})

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]
df.head()
# Out:
#   Unnamed: 0_level_0_Squad  Unnamed: 1_level_0_# Pl  Unnamed: 2_level_0_Age  \
# 0                  Arsenal                       23                    26.4
# 1              Aston Villa                       23                    28.4
# 2              Bournemouth                       24                    25.6
# 3                Brentford                       21                    25.4
# 4                 Brighton                       24                    26.0
#
#    Unnamed: 3_level_0_Poss  Playing Time_MP  Playing Time_Starts  \
# 0                     58.5               11                  121
# 1                     53.7               11                  121
# 2                     50.5               11                  121
# 3                     43.5               11                  121
# 4                     48.8               11                  121
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  ...  \
# 0               990              11.0               20               14  ...
# 1               990              11.0               13               10  ...
# 2               990              11.0               17               11  ...
# 3               990              11.0               17                8  ...
# 4               990              11.0               17               11  ...
#
#    Per 90 Minutes_Gls  Per 90 Minutes_Ast  Per 90 Minutes_G+A  \
# 0                1.82                1.27                3.09
# 1                1.18                0.91                2.09
# 2                1.55                1.00                2.55
# 3                1.55                0.73                2.27
# 4                1.55                1.00                2.55
#
#    Per 90 Minutes_G-PK  Per 90 Minutes_G+A-PK  Per 90 Minutes_xG  \
# 0                 1.64                   2.91               1.71
# 1                 1.18                   2.09               0.83
# 2                 1.45                   2.45               1.20
# 3                 1.27                   2.00               1.48
# 4                 1.36                   2.36               1.51
#
#    Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  \
# 0                1.05                   2.76                 1.57
# 1                0.65                   1.48                 0.83
# 2                0.74                   1.94                 1.06
# 3                0.90                   2.38                 1.20
# 4                1.01                   2.52                 1.30
#
#    Per 90 Minutes_npxG+xAG
# 0                     2.61
# 1                     1.48
# 2                     1.80
# 3                     2.10
# 4                     2.32
#
# [5 rows x 32 columns]

# %%
df = df.rename(columns={
    "Unnamed: 0_level_0_Squad": "Squad",
    "Unnamed: 1_level_0_# Pl": "Players",
    "Unnamed: 2_level_0_Age": "Avg_player_age",
    "Unnamed: 3_level_0_Poss": "Possession"
})
df.head()
# Out:
#          Squad  Players  Avg_player_age  Possession  Playing Time_MP  \
# 0      Arsenal       23            26.4        58.5               11
# 1  Aston Villa       23            28.4        53.7               11
# 2  Bournemouth       24            25.6        50.5               11
# 3    Brentford       21            25.4        43.5               11
# 4     Brighton       24            26.0        48.8               11
#
#    Playing Time_Starts  Playing Time_Min  Playing Time_90s  Performance_Gls  \
# 0                  121               990              11.0               20
# 1                  121               990              11.0               13
# 2                  121               990              11.0               17
# 3                  121               990              11.0               17
# 4                  121               990              11.0               17
#
#    Performance_Ast  ...  Per 90 Minutes_Gls  Per 90 Minutes_Ast  \
# 0               14  ...                1.82                1.27
# 1               10  ...                1.18                0.91
# 2               11  ...                1.55                1.00
# 3                8  ...                1.55                0.73
# 4               11  ...                1.55                1.00
#
#    Per 90 Minutes_G+A  Per 90 Minutes_G-PK  Per 90 Minutes_G+A-PK  \
# 0                3.09                 1.64                   2.91
# 1                2.09                 1.18                   2.09
# 2                2.55                 1.45                   2.45
# 3                2.27                 1.27                   2.00
# 4                2.55                 1.36                   2.36
#
#    Per 90 Minutes_xG  Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  \
# 0               1.71                1.05                   2.76
# 1               0.83                0.65                   1.48
# 2               1.20                0.74                   1.94
# 3               1.48                0.90                   2.38
# 4               1.51                1.01                   2.52
#
#    Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# 0                 1.57                     2.61
# 1                 0.83                     1.48
# 2                 1.06                     1.80
# 3                 1.20                     2.10
# 4                 1.30                     2.32
#
# [5 rows x 32 columns]

# %%
df.to_csv("squad_standard_stats_2025-2026.csv", index=False)

# %%
data = pd.read_csv("squad_standard_stats_2025-2026.csv")
data.head()
# Out:
#          Squad  Players  Avg_player_age  Possession  Playing Time_MP  \
# 0      Arsenal       23            26.4        58.5               11
# 1  Aston Villa       23            28.4        53.7               11
# 2  Bournemouth       24            25.6        50.5               11
# 3    Brentford       21            25.4        43.5               11
# 4     Brighton       24            26.0        48.8               11
#
#    Playing Time_Starts  Playing Time_Min  Playing Time_90s  Performance_Gls  \
# 0                  121               990              11.0               20
# 1                  121               990              11.0               13
# 2                  121               990              11.0               17
# 3                  121               990              11.0               17
# 4                  121               990              11.0               17
#
#    Performance_Ast  ...  Per 90 Minutes_Gls  Per 90 Minutes_Ast  \
# 0               14  ...                1.82                1.27
# 1               10  ...                1.18                0.91
# 2               11  ...                1.55                1.00
# 3                8  ...                1.55                0.73
# 4               11  ...                1.55                1.00
#
#    Per 90 Minutes_G+A  Per 90 Minutes_G-PK  Per 90 Minutes_G+A-PK  \
# 0                3.09                 1.64                   2.91
# 1                2.09                 1.18                   2.09
# 2                2.55                 1.45                   2.45
# 3                2.27                 1.27                   2.00
# 4                2.55                 1.36                   2.36
#
#    Per 90 Minutes_xG  Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  \
# 0               1.71                1.05                   2.76
# 1               0.83                0.65                   1.48
# 2               1.20                0.74                   1.94
# 3               1.48                0.90                   2.38
# 4               1.51                1.01                   2.52
#
#    Per 90 Minutes_npxG  Per 90 Minutes_npxG+xAG
# 0                 1.57                     2.61
# 1                 0.83                     1.48
# 2                 1.06                     1.80
# 3                 1.20                     2.10
# 4                 1.30                     2.32
#
# [5 rows x 32 columns]

# %%
# %pip install soccerdata
# Out:
# Collecting soccerdata
#   Downloading soccerdata-1.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: PySocks<2.0.0,>=1.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from soccerdata) (1.7.1)
# Requirement already satisfied: Unidecode<2.0.0,>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from soccerdata) (1.3.8)
# Collecting html5lib<2.0,>=1.1 (from soccerdata)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting lxml<5.0,>=4.6 (from soccerdata)
#   Downloading lxml-4.9.4.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 15.7 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... one
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from soccerdata) (2.2.3)
# Requirement already satisfied: requests<3.0,>=2.23 in /opt/anaconda3/lib/python3.13/site-packages (from soccerdata) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from soccerdata) (13.9.4)
# Collecting undetected-chromedriver<4.0.0,>=3.5.0 (from soccerdata)
#   Downloading undetected-chromedriver-3.5.5.tar.gz (65 kB)
#   Preparing metadata (setup.py) ... done
# Collecting unicode<3.0,>=2.7 (from soccerdata)
#   Downloading unicode-2.9-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from html5lib<2.0,>=1.1->soccerdata) (1.17.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.13/site-packages (from html5lib<2.0,>=1.1->soccerdata) (0.5.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.0.0,>=2.0.0->soccerdata) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.0.0,>=2.0.0->soccerdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.0.0,>=2.0.0->soccerdata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3.0.0,>=2.0.0->soccerdata) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0,>=2.23->soccerdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0,>=2.23->soccerdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0,>=2.23->soccerdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0,>=2.23->soccerdata) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich<14.0.0,>=13.0.0->soccerdata) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich<14.0.0,>=13.0.0->soccerdata) (2.19.1)
# Collecting selenium>=4.9.0 (from undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting websockets (from undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->soccerdata) (0.1.0)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.23->soccerdata)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (24.3.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (2.4.0)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.3.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata)
#   Downloading wsproto-1.3.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: h11<1,>=0.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (0.16.0)
# Downloading soccerdata-1.5.1-py3-none-any.whl (42 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading unicode-2.9-py2.py3-none-any.whl (14 kB)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 8.8 MB/s eta 0:00:008.4 MB/s eta 0:00:01m
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.1-py3-none-any.whl (24 kB)
# Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Building wheels for collected packages: lxml, undetected-chromedriver
#   DEPRECATION: Building 'lxml' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'lxml'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for lxml (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [254 lines of output]
#       Building lxml version 4.9.4.
#       /private/var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T/pip-install-do58afvt/lxml_3a921f9b5c324046a62afa1ad324b40e/setup.py:67: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         import pkg_resources
#       Building without Cython.
#       Building against libxml2 2.13.8 and libxslt 1.1.41
#       Building against libxml2/libxslt in one of the following directories:
#         /opt/anaconda3/lib
#         /opt/anaconda3/lib
#         /opt/anaconda3/lib
#         /opt/anaconda3/lib
#         /opt/anaconda3/lib
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-313
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/_elementpath.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/sax.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/pyclasslookup.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/__init__.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/builder.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/doctestcompare.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/usedoctest.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/cssselect.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/ElementInclude.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/__init__.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/soupparser.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/defs.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/_setmixin.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/clean.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/_diffcommand.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/html5parser.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/__init__.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/formfill.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/builder.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/ElementSoup.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/_html5builder.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/usedoctest.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       copying src/lxml/html/diff.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/html
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron
#       copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron
#       copying src/lxml/etree.h -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/etree_api.h -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/lxml.etree.h -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/lxml.etree_api.h -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/objectify.pyx -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/etree.pyx -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/public-api.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xmlid.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/cleanup.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xslt.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xpath.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/debug.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/serializer.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/classlookup.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/saxparser.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/objectpath.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/relaxng.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xinclude.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/iterparse.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/parser.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/dtd.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/apihelpers.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xmlerror.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/readonlytree.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/extensions.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xmlschema.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/schematron.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/docloader.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/nsclasses.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/parsertarget.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/xsltext.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/proxy.pxi -> build/lib.macosx-11.1-arm64-cpython-313/lxml
#       copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/c14n.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/schematron.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/tree.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/uri.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/xpath.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/xslt.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/config.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/lxml-version.h -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       copying src/lxml/includes/etree_defs.h -> build/lib.macosx-11.1-arm64-cpython-313/lxml/includes
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/rng
#       copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/rng
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl
#       creating build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-11.1-arm64-cpython-313/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       running build_ext
#       building 'lxml.etree' extension
#       creating build/temp.macosx-11.1-arm64-cpython-313
#       creating build/temp.macosx-11.1-arm64-cpython-313/src
#       creating build/temp.macosx-11.1-arm64-cpython-313/src/lxml
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DCYTHON_CLINE_IN_TRACEBACK=0 -I/opt/anaconda3/include/libxml2 -I/opt/anaconda3/include -Isrc -Isrc/lxml/includes -I/opt/anaconda3/include/python3.13 -c src/lxml/etree.c -o build/temp.macosx-11.1-arm64-cpython-313/src/lxml/etree.o -w -flat_namespace
#       src/lxml/etree.c:5988:39: error: call to undeclared function '_PyInterpreterState_GetConfig'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#        5988 |     __pyx_assertions_enabled_flag = ! _PyInterpreterState_GetConfig(__Pyx_PyThreadState_Current->interp)->optimization_level;
#             |                                       ^
#       src/lxml/etree.c:5988:107: error: member reference type 'int' is not a pointer
#        5988 |     __pyx_assertions_enabled_flag = ! _PyInterpreterState_GetConfig(__Pyx_PyThreadState_Current->interp)->optimization_level;
#             |                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  ^
#       src/lxml/etree.c:113221:38: error: incompatible function pointer types assigning to 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') from 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        113221 |   __pyx_v_self->_c_ctxt->sax->serror = __pyx_f_4lxml_5etree__receiveParserError;
#               |                                      ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       src/lxml/etree.c:117709:25: error: incompatible function pointer types assigning to 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') from 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        117709 |     __pyx_v_sax->serror = __pyx_f_4lxml_5etree__receiveParserError;
#               |                         ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       src/lxml/etree.c:181971:28: error: incompatible function pointer types assigning to 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') from 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        181971 |   __pyx_v_xpathCtxt->error = __pyx_f_4lxml_5etree__receiveXPathError;
#               |                            ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       src/lxml/etree.c:219245:60: error: incompatible function pointer types passing 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') to parameter of type 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        219245 |   xmlRelaxNGSetParserStructuredErrors(__pyx_v_parser_ctxt, __pyx_f_4lxml_5etree__receiveError, ((void *)__pyx_v_self->__pyx_base._error_log));
#               |                                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/anaconda3/include/libxml2/libxml/relaxng.h:156:30: note: passing argument to parameter 'serror' here
#         156 |                                          xmlStructuredErrorFunc serror,
#             |                                                                 ^
#       src/lxml/etree.c:219663:60: error: incompatible function pointer types passing 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') to parameter of type 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        219663 |     xmlRelaxNGSetValidStructuredErrors(__pyx_v_valid_ctxt, __pyx_f_4lxml_5etree__receiveError, ((void *)__pyx_v_self->__pyx_base._error_log));
#               |                                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/anaconda3/include/libxml2/libxml/relaxng.h:185:31: note: passing argument to parameter 'serror' here
#         185 |                                           xmlStructuredErrorFunc serror, void *ctx);
#             |                                                                  ^
#       src/lxml/etree.c:220552:59: error: incompatible function pointer types passing 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') to parameter of type 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        220552 |   xmlSchemaSetParserStructuredErrors(__pyx_v_parser_ctxt, __pyx_f_4lxml_5etree__receiveError, ((void *)__pyx_v_self->__pyx_base._error_log));
#               |                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/anaconda3/include/libxml2/libxml/xmlschemas.h:156:30: note: passing argument to parameter 'serror' here
#         156 |                                          xmlStructuredErrorFunc serror,
#             |                                                                 ^
#       src/lxml/etree.c:221095:59: error: incompatible function pointer types passing 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') to parameter of type 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        221095 |     xmlSchemaSetValidStructuredErrors(__pyx_v_valid_ctxt, __pyx_f_4lxml_5etree__receiveError, ((void *)__pyx_v_self->__pyx_base._error_log));
#               |                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/anaconda3/include/libxml2/libxml/xmlschemas.h:185:30: note: passing argument to parameter 'serror' here
#         185 |                                          xmlStructuredErrorFunc serror,
#             |                                                                 ^
#       src/lxml/etree.c:221860:66: error: incompatible function pointer types passing 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') to parameter of type 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        221860 |     xmlSchemaSetValidStructuredErrors(__pyx_v_self->_valid_ctxt, __pyx_f_4lxml_5etree__receiveError, ((void *)__pyx_v_error_log));
#               |                                                                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/anaconda3/include/libxml2/libxml/xmlschemas.h:185:30: note: passing argument to parameter 'serror' here
#         185 |                                          xmlStructuredErrorFunc serror,
#             |                                                                 ^
#       src/lxml/etree.c:223037:63: error: incompatible function pointer types passing 'void (void *, xmlError *)' (aka 'void (void *, struct _xmlError *)') to parameter of type 'xmlStructuredErrorFunc' (aka 'void (*)(void *, const struct _xmlError *)') [-Wincompatible-function-pointer-types]
#        223037 |     xmlSchematronSetValidStructuredErrors(__pyx_v_valid_ctxt, __pyx_f_4lxml_5etree__receiveError, ((void *)__pyx_v_self->__pyx_base._error_log));
#               |                                                               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /opt/anaconda3/include/libxml2/libxml/schematron.h:106:31: note: passing argument to parameter 'serror' here
#         106 |                                           xmlStructuredErrorFunc serror,
#             |                                                                  ^
#       src/lxml/etree.c:255376:7: error: call to undeclared function '_PyDict_SetItem_KnownHash'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#        255376 |   if (__Pyx_SetNameInClass(__pyx_t_2, __pyx_n_s_getitem, __pyx_t_9) < 0) __PYX_ERR(0, 97, __pyx_L1_error)
#               |       ^
#       src/lxml/etree.c:6652:38: note: expanded from macro '__Pyx_SetNameInClass'
#        6652 |     (likely(PyDict_CheckExact(ns)) ? _PyDict_SetItem_KnownHash(ns, name, value, ((PyASCIIObject *) name)->hash) : PyObject_SetItem(ns, name, value))
#             |                                      ^
#       src/lxml/etree.c:255376:7: note: did you mean '_PyDict_GetItem_KnownHash'?
#       src/lxml/etree.c:6652:38: note: expanded from macro '__Pyx_SetNameInClass'
#        6652 |     (likely(PyDict_CheckExact(ns)) ? _PyDict_SetItem_KnownHash(ns, name, value, ((PyASCIIObject *) name)->hash) : PyObject_SetItem(ns, name, value))
#             |                                      ^
#       /opt/anaconda3/include/python3.13/cpython/dictobject.h:38:24: note: '_PyDict_GetItem_KnownHash' declared here
#          38 | PyAPI_FUNC(PyObject *) _PyDict_GetItem_KnownHash(PyObject *mp, PyObject *key,
#             |                        ^
#       src/lxml/etree.c:264446:13: error: call to undeclared function '_PyUnicode_FastCopyCharacters'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#        264446 |             _PyUnicode_FastCopyCharacters(result_uval, char_pos, uval, 0, ulength);
#               |             ^
#       src/lxml/etree.c:264446:13: note: did you mean 'PyUnicode_CopyCharacters'?
#       /opt/anaconda3/include/python3.13/cpython/unicodeobject.h:416:24: note: 'PyUnicode_CopyCharacters' declared here
#         416 | PyAPI_FUNC(Py_ssize_t) PyUnicode_CopyCharacters(
#             |                        ^
#       src/lxml/etree.c:265182:35: error: use of undeclared identifier '_PyObject_NextNotImplemented'; did you mean 'PyObject_HashNotImplemented'?
#        265182 |         if (unlikely(iternext == &_PyObject_NextNotImplemented))
#               |                                   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#               |                                   PyObject_HashNotImplemented
#       src/lxml/etree.c:1096:43: note: expanded from macro 'unlikely'
#        1096 |   #define unlikely(x) __builtin_expect(!!(x), 0)
#             |                                           ^
#       /opt/anaconda3/include/python3.13/object.h:591:23: note: 'PyObject_HashNotImplemented' declared here
#         591 | PyAPI_FUNC(Py_hash_t) PyObject_HashNotImplemented(PyObject *);
#             |                       ^
#       src/lxml/etree.c:265973:13: error: call to undeclared function '_PyGen_SetStopIterationValue'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#        265973 |             _PyGen_SetStopIterationValue(result);
#               |             ^
#       src/lxml/etree.c:265973:13: note: did you mean '__Pyx_PyGen__FetchStopIterationValue'?
#       src/lxml/etree.c:265728:12: note: '__Pyx_PyGen__FetchStopIterationValue' declared here
#        265728 | static int __Pyx_PyGen__FetchStopIterationValue(CYTHON_UNUSED PyThreadState *__pyx_tstate, PyObject **pvalue) {
#               |            ^
#       src/lxml/etree.c:267806:5: error: call to undeclared function '_PyErr_FormatFromCause'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#        267806 |     _PyErr_FormatFromCause(
#               |     ^
#       src/lxml/etree.c:268071:19: error: call to undeclared function '_PySet_NextEntry'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#        268071 |         int ret = _PySet_NextEntry(iter_obj, ppos, value, &hash);
#               |                   ^
#       src/lxml/etree.c:269068:70: error: too few arguments to function call, expected 6, have 5
#        269066 |                 int ret = _PyLong_AsByteArray((PyLongObject *)v,
#               |                           ~~~~~~~~~~~~~~~~~~~
#        269067 |                                               bytes, sizeof(val),
#        269068 |                                               is_little, !is_unsigned);
#               |                                                                      ^
#       /opt/anaconda3/include/python3.13/cpython/longobject.h:111:17: note: '_PyLong_AsByteArray' declared here
#         111 | PyAPI_FUNC(int) _PyLong_AsByteArray(PyLongObject* v,
#             |                 ^                   ~~~~~~~~~~~~~~~~
#         112 |     unsigned char* bytes, size_t n,
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         113 |     int little_endian, int is_signed, int with_exceptions);
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       src/lxml/etree.c:269377:70: error: too few arguments to function call, expected 6, have 5
#        269375 |                 int ret = _PyLong_AsByteArray((PyLongObject *)v,
#               |                           ~~~~~~~~~~~~~~~~~~~
#        269376 |                                               bytes, sizeof(val),
#        269377 |                                               is_little, !is_unsigned);
#               |                                                                      ^
#       /opt/anaconda3/include/python3.13/cpython/longobject.h:111:17: note: '_PyLong_AsByteArray' declared here
#         111 | PyAPI_FUNC(int) _PyLong_AsByteArray(PyLongObject* v,
#             |                 ^                   ~~~~~~~~~~~~~~~~
#         112 |     unsigned char* bytes, size_t n,
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         113 |     int little_endian, int is_signed, int with_exceptions);
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       fatal error: too many errors emitted, stopping now [-ferror-limit=]
#       20 errors generated.
#       Compile failed: command '/usr/bin/clang' failed with exit code 1
#       creating var
#       creating var/folders
#       creating var/folders/dg
#       creating var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn
#       creating var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T
#       cc -I/opt/anaconda3/include/libxml2 -I/opt/anaconda3/include -I/usr/include/libxml2 -c /var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T/xmlXPathInity_3r1lo6.c -o var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T/xmlXPathInity_3r1lo6.o
#       /var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T/xmlXPathInity_3r1lo6.c:3:5: warning: 'xmlXPathInit' is deprecated [-Wdeprecated-declarations]
#           3 |     xmlXPathInit();
#             |     ^
#       /opt/anaconda3/include/libxml2/libxml/xpath.h:566:1: note: 'xmlXPathInit' has been explicitly marked deprecated here
#         566 | XML_DEPRECATED
#             | ^
#       /opt/anaconda3/include/libxml2/libxml/xmlexports.h:69:43: note: expanded from macro 'XML_DEPRECATED'
#          69 |     #define XML_DEPRECATED __attribute__((deprecated))
#             |                                           ^
#       1 warning generated.
#       cc var/folders/dg/93wvghd5137cglm9mr9b58zh0000gn/T/xmlXPathInity_3r1lo6.o -L/opt/anaconda3/lib -L/opt/anaconda3/lib -L/opt/anaconda3/lib -L/opt/anaconda3/lib -L/opt/anaconda3/lib -lxml2 -o a.out
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for lxml
#   Running setup.py clean for lxml
#   DEPRECATION: Building 'undetected-chromedriver' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'undetected-chromedriver'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for undetected-chromedriver (setup.py) ... one
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.5-py3-none-any.whl size=47048 sha256=0411a902bcca7207276450c8ca4d53036c790ee8fc3dc178adf7365f8a782834
#   Stored in directory: /Users/renedapon/Library/Caches/pip/wheels/7a/5f/c1/06f68421cc7172ef51504631252870bcb3a2fdf3b6a025f362
# Successfully built undetected-chromedriver
# Failed to build lxml
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (lxml)
# Note: you may need to restart the kernel to use updated packages.
